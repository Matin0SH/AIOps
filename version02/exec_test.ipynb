# %%
from graph.cypher import *

test0 = show_cdp_neighbors_device_tool.invoke({"device": "CORE-SW1"})
test1 = show_ospf_neighbors_tool.invoke({})
test2 = show_interfaces_connected_device_tool.invoke({"device": "CORE-SW1"})
test3 = show_ospf_neighbors_device_tool.invoke({"device": "CORE-SW1"})
# Out:
# c:\Matin\codes\myenv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
test4 = show_shortest_path_tool.invoke({"device": "CORE-SW1"})

# %%
test2
# Out:
# [{'local_iface': 'GigabitEthernet1/0',
#   'remote_device': 'ACC-SW1',
#   'remote_iface': 'GigabitEthernet0/1',
#   'protocol': 'CDP'},
#  {'local_iface': 'GigabitEthernet1/1',
#   'remote_device': 'ACC-SW2',
#   'remote_iface': 'GigabitEthernet0/1',
#   'protocol': 'CDP'},
#  {'local_iface': 'GigabitEthernet0/2',
#   'remote_device': 'CORE-SW2',
#   'remote_iface': 'GigabitEthernet0/2',
#   'protocol': 'CDP'},
#  {'local_iface': 'GigabitEthernet0/3',
#   'remote_device': 'CORE-SW2',
#   'remote_iface': 'GigabitEthernet0/3',
#   'protocol': 'CDP'},
#  {'local_iface': 'GigabitEthernet0/1',
#   'remote_device': 'MANAGEMENT',
#   'remote_iface': 'GigabitEthernet0/2',
#   'protocol': 'CDP'}]

# %%
from tools.executor import set_device_config, execute_notebook

# 1) Set device connection (MANAGEMENT)
set_device_config(
    host="192.168.56.101",
    port=5002,              # update to your MANAGEMENT port
    username="",
    password="",
    enable_secret="cisco"
)
# Out:
# c:\Matin\codes\myenv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# INFO:tools.executor:Device config set: 192.168.56.101:5002

# %%
# 2) Dry-run a notebook (no changes)
result = execute_notebook.invoke({
    "notebook_id": "cfg_create_vlan",
    "params": {"vlan_id": 10, "vlan_name": "MANAGEMENT"},
    "dry_run": False
})
# Out:
# INFO:tools.executor:Executed notebook 'cfg_create_vlan' - Success: True, Dry Run: False

# %%
result
# Out:
# {'success': True,
#  'notebook_id': 'cfg_create_vlan',
#  'title': 'Create VLAN and set name',
#  'description': "Creates a new Layer 2 VLAN and assigns a descriptive name for identification. VLANs segment broadcast domains and improve network organization. Medium-risk configuration that by itself doesn't affect traffic until interfaces are assigned. Name should be meaningful for documentation. Essential for any segmented switched network.",
#  'risk': 'medium',
#  'commands_sent': ['vlan 10', 'name MANAGEMENT', 'exit'],
#  'device_output': '\nMANAGEMENT#configure terminal\nEnter configuration commands, one per line.  End with CNTL/Z.\nMANAGEMENT(config)#\nMANAGEMENT(config)#\nMANAGEMENT(config)#vlan 10\nMANAGEMENT(config-vlan)#\n\nMANAGEMENT(config-vlan)#name MANAGEMENT\nMANAGEMENT(config-vlan)#\nMANAGEMENT(config-vlan)#exit\nMANAGEMENT(co\nMANAGEMENT(config)#\nMANAGEMENT(config)#\nMANAGEMENT(config)#end\nMANAGEMENT#',
#  'dry_run': False,
#  'validated': True,
# ...
